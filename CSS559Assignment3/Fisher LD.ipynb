# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def mean(X):
    X_mean=np.mean(X,axis=0)
    return X_mean

# %%
C1=np.array([[-2,1],[-5,-4],[-3,1],[0,-3],[-8,-1]])
C2=np.array([[2,5],[1,0],[5,-1],[-1,-3],[6,1]])

# %%
M1=np.mean(C1,axis=0)
M2=np.mean(C2,axis=0)

# %%
S1=(C1.shape[0]-1)*np.cov(C1.T)
S2=(C2.shape[0]-1)*np.cov(C2.T)

# %%
S1
# Out:
# array([[37.2,  1.4],
#        [ 1.4, 20.8]])

# %%
S_W=S1+S2

# %%
np.linalg.inv(S_W)
# Out:
# array([[ 0.01458956, -0.00265738],
#        [-0.00265738,  0.01834117]])

# %%
Optimal_components=np.dot(np.linalg.inv(S_W),M1-M2)

# %%
print("Optimal Line Direction: ")
print(Optimal_components)
# Out:
# Optimal Line Direction:
# [-0.08620348 -0.01287008]

# %%
test_class1=np.dot(class1,Optimal_components)
test_class2=np.dot(class2,Optimal_components)

# %%
test_class2
# Out:
# array([-0.23675737, -0.08620348, -0.41814733,  0.12481372, -0.53009098])

# %%
print("correctly clasified points :")
for i in range(class1.shape[0]):
    if(test_class1[i]>0):
        print(class1[i])
for i in range(class2.shape[0]):
    if(test_class2[i]<0):
        print(class2[i])
# Out:
# correctly clasified points :
# [-2  1]
# [-5 -4]
# [-3  1]
# [ 0 -3]
# [-8 -1]
# [2 5]
# [1 0]
# [ 5 -1]
# [6 1]

# %%
print("incorrectly clasified points :")
for i in range(class1.shape[0]):
    if(test_class1[i]<0):
        print(class1[i])
for i in range(class2.shape[0]):
    if(test_class2[i]>0):
        print(class2[i])
# Out:
# incorrectly clasified points :
# [-1 -3]
